# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Layering: divide the data into N layers, make sure every layer has the same distribution of 0-1

# %% [markdown]
# ## load 2017 train

# %%
df = pd.read_table('../data/water/txt/2017waterDataTraining.txt',delim_whitespace=True)

# %%
df = df.reset_index()
Time = np.zeros(df.shape[0]).astype("str")
for i in range(len(df)):
    Time[i] = df['index'][i]+" "+ df['Time'][i]
df['Time'] = Time
df = df.drop(['index'], axis=1)

# %% [markdown]
# ## feature engineering
#
#
# It looks like we have 14 columns to help us predict our classification. We will drop fnlwgt and education and then convert our categorical features to dummy variables. We will also convert our label to 0 and 1 where 1 means the person made more than $50k

# %%
drop_columns = ['Time']
continuous_features = ['Tp', 'Cl', 'pH', 'Redox', 'Leit', 'Trueb', 'Cl_2', 'Fm', 'Fm_2']
cat_features =[]

# %%
all_df_dummies = pd.get_dummies(df, columns=cat_features)

# %%
all_df_dummies.drop(drop_columns, 1, inplace=True)
# delte NA datas
all_df_dummies = all_df_dummies.dropna(axis=0)

# %%
X_train = all_df_dummies.drop(['EVENT'], axis=1) # Series
y_train = all_df_dummies['EVENT'].apply(lambda x: 0 if x == False else 1) # Series

# %%
train = pd.concat([X_train,y_train], axis=1)

# %%
train.head()
# Out:
#     Tp    Cl    pH  Redox   Leit  Trueb   Cl_2      Fm    Fm_2  EVENT
# 0  4.4  0.14  8.38  755.0  232.0  0.009  0.110  1428.0  1020.0      0
# 1  4.4  0.14  8.38  755.0  232.0  0.009  0.111  1436.0  1018.0      0
# 2  4.4  0.14  8.38  755.0  232.0  0.014  0.113  1471.0  1019.0      0
# 3  4.4  0.14  8.37  755.0  232.0  0.015  0.111  1457.0  1015.0      0
# 4  4.4  0.14  8.38  755.0  232.0  0.013  0.111  1476.0  1019.0      0

# %%
train.to_csv('../data/water/csv/train2017.csv', encoding='utf-8', index=False)

# %% [markdown]
# #### layer sampling

# %%
# print("============ layer sampling ============")
# train_layer = Layering(train, kf)
# array = train_layer.values
# X_train = array[:, 0:-1] # ndarray
# y_train = array[:, -1] # ndarray

# %% [markdown]
# Train/Validation Split

# %%
# X_tr, X_vld, y_tr, y_vld = train_test_split(X_train, y_train, test_size=valid_size,
#                                                 stratify = y_train, random_state = random_seed)
# # stratify： 按正负样本原始比例random_seed分配给train 和 valid

# %% [markdown]
# #### Do somte sampling on the train data to solve data imblance problem

# %%
# X_train_oversampled, y_train_oversampled = Smoter(X_tr, y_tr, is_random=True)
# print("============ SMOTE ============")
# print("train: %d, contains %.4f of 0 , after SMOTE: train: %d contains %.4f of 1" %(X_train.shape[0], (y_train == 0).sum()/y_train.shape[0], X_train_oversampled.shape[0], (y_train_oversampled == 0).sum()/y_train_oversampled.shape[0]))

# %% [markdown]
# ### normalize the train and valid
#
# fulfill the Na with median, then standardized the data, output type ndarray

# %%
# clean_pipeline = Pipeline([('imputer', preprocessing.Imputer(missing_values='NaN',strategy="median")),
#                            ('std_scaler', preprocessing.StandardScaler()),])
# X_train_oversampled = clean_pipeline.fit_transform(X_train_oversampled)
# X_vld = clean_pipeline.fit_transform(X_vld)

# %% [markdown]
# ### transfer y into probability vector

# %%
# y_train_oversampled_pro = np.zeros([y_train_oversampled.shape[0], 2])
# for i in range(len(y_train_oversampled)):
#     if y_train_oversampled[i] == 1:
#         y_train_oversampled_pro[i] = np.array([0, 1])
#     else:
#         y_train_oversampled_pro[i] = np.array([1, 0])
# y_train_oversampled = y_train_oversampled_pro    

# y_vld_pro = np.zeros([y_vld.shape[0], 2])
# for i in range(len(y_vld)):
#     if y_vld[i] == 1:
#         y_vld_pro[i] = np.array([0, 1])
#     else:
#         y_vld_pro[i] = np.array([1, 0])
# y_vld = y_vld_pro

# %% [markdown]
# ## load 2017 test

# %%
lines = open("../data/water/txt/2017waterDataTesting.txt").readlines()
num_lines = len(lines) - 1

X_test = np.ones((num_lines, 9))
y_test = np.ones((num_lines, 1))
flag = 0

lines = np.delete(lines, 0, axis = 0)
i = 0

for line in lines:
    data_line = line.split()
    feature = data_line[3:12]
    for k in range(9):
        if feature[k] == 'NA':
            flag = 1
            break
    if flag == 1:
        flag = 0
        continue    # jump out of the loop
    X_test[i] = feature    
    if data_line[12] == 'FALSE':
        y_test[i] = 0
    elif data_line[12] == 'TRUE':
        y_test[i] = 1
    i += 1


# X_test = clean_pipeline.fit_transform(X_test) 

test = np.concatenate([X_test, y_test], axis=1)

# y_test_pro = np.zeros([y_test.shape[0], 2])
# for i in range(len(y_test)):
#     if y_test[i] == 1:
#         y_test_pro[i] = np.array([0, 1])
#     else:
#         y_test_pro[i] = np.array([1, 0])
# y_test = y_test_pro

# %%
test = pd.DataFrame(test, columns =['Tp', 'Cl', 'pH', 'Redox', 'Leit', 'Trueb', 'Cl_2', 'Fm', 'Fm_2', 'EVENT'])
test.head()
# Out:
#          Tp    Cl    pH  Redox   Leit  Trueb   Cl_2      Fm    Fm_2  EVENT
# 0       4.4  0.14  8.38  755.0  232.0  0.009  0.110  1428.0  1020.0    0.0
# 1       4.4  0.14  8.38  755.0  232.0  0.009  0.111  1436.0  1018.0    0.0
# 2       4.4  0.14  8.38  755.0  232.0  0.014  0.113  1471.0  1019.0    0.0
# 3       4.4  0.14  8.37  755.0  232.0  0.015  0.111  1457.0  1015.0    0.0
# 4       4.4  0.14  8.38  755.0  232.0  0.013  0.111  1476.0  1019.0    0.0
# 5       4.4  0.14  8.36  755.0  232.0  0.013  0.114  1416.0  1015.0    0.0
# 6       4.4  0.14  8.36  755.0  235.0  0.012  0.111  1452.0  1017.0    0.0
# 7       4.4  0.14  8.36  755.0  232.0  0.011  0.111  1445.0  1013.0    0.0
# 8       4.4  0.14  8.36  755.0  232.0  0.012  0.113  1465.0  1008.0    0.0
# 9       4.4  0.14  8.36  755.0  235.0  0.014  0.113  1482.0  1017.0    0.0
# 10      4.4  0.14  8.36  755.0  232.0  0.018  0.114  1489.0  1020.0    0.0
# 11      4.4  0.14  8.36  755.0  232.0  0.013  0.114  1471.0  1018.0    0.0
# 12      4.4  0.14  8.36  755.0  232.0  0.017  0.113  1497.0  1006.0    0.0
# 13      4.4  0.14  8.36  755.0  232.0  0.013  0.111  1452.0  1008.0    0.0
# 14      4.4  0.14  8.36  755.0  232.0  0.011  0.111  1472.0  1015.0    0.0
# 15      4.4  0.14  8.36  755.0  235.0  0.018  0.111  1562.0  1012.0    0.0
# 16      4.4  0.14  8.36  755.0  232.0  0.016  0.111  1517.0  1012.0    0.0
# 17      4.4  0.14  8.36  755.0  235.0  0.015  0.111  1446.0  1015.0    0.0
# 18      4.4  0.14  8.36  755.0  232.0  0.013  0.111  1460.0  1009.0    0.0
# 19      4.4  0.14  8.36  755.0  232.0  0.012  0.111  1472.0  1020.0    0.0
# 20      4.4  0.14  8.36  755.0  235.0  0.017  0.113  1410.0  1026.0    0.0
# 21      4.4  0.14  8.36  755.0  235.0  0.012  0.111  1453.0  1015.0    0.0
# 22      4.4  0.14  8.35  755.0  235.0  0.014  0.113  1425.0  1015.0    0.0
# 23      4.4  0.14  8.34  755.0  235.0  0.011  0.113  1442.0  1018.0    0.0
# 24      4.4  0.13  8.34  755.0  235.0  0.013  0.110  1454.0  1013.0    0.0
# 25      4.4  0.14  8.34  755.0  235.0  0.012  0.111  1445.0  1018.0    0.0
# 26      4.4  0.14  8.34  755.0  235.0  0.011  0.111  1482.0  1018.0    0.0
# 27      4.4  0.14  8.34  755.0  235.0  0.018  0.113  1418.0  1017.0    0.0
# 28      4.4  0.14  8.34  755.0  232.0  0.015  0.112  1469.0  1013.0    0.0
# 29      4.4  0.14  8.34  755.0  232.0  0.017  0.114  1453.0  1012.0    0.0
# ...     ...   ...   ...    ...    ...    ...    ...     ...     ...    ...
# 244638  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244639  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244640  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244641  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244642  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244643  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244644  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244645  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244646  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244647  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244648  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244649  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244650  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244651  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244652  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244653  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244654  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244655  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244656  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244657  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244658  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244659  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244660  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244661  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244662  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244663  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244664  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244665  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244666  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
# 244667  1.0  1.00  1.00    1.0    1.0  1.000  1.000     1.0     1.0    1.0
#
# [244668 rows x 10 columns]

# %%
test.to_csv('../data/water/csv/test2017.csv', encoding='utf-8', index=False)
